# %%
# processing images
import  cv2

# %%
# checking version
cv2.__version__
# Out:
# '4.1.0'

# %%
#reading an image file
img1=cv2.imread('mini.jpg')
img2=cv2.imread('mini.png')

# %%
img2.shape
# Out:
# (621, 350, 3)

# %%
# showing   image
import  matplotlib.pyplot  as plt

# %%
plt.imshow(img2)
